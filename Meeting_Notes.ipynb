# %% [markdown]
# ### Steps to do:
# - [x] Plot individual component of portfolio
# - [x] Plot delta hedging trajectory
# - [ ] Add small Gaussian error to each paramater and see how it affects delta hedging error
# - [ ] Use squared log return for estimator for volatility vs true volatility (since IRL we don't know true vol)
#     - Want to smooth return before using it for estimator so it's independent of vol of vol
# - [ ] Implement clipping smoother from class
#     - [ ] Change $\theta$ or $\sigma$ to see which has more effect on smoothing
#     - [ ] If increase $\kappa$ and $\theta$ together, expect less effectiveness because higher mean-reversion rate
# - [ ] Use elastic net estimator and derive influence function
